# %% [markdown]
# Urutan diagram pipeline untuk membuat model yang nantinya akan dijalankan secara otomatis oleh tim Ops, sebagai berikut:
#
#
#
# 1.  Import Data
# 2.  Data Imputation
# 3. Feature Engineering & Selection: Feature engineering adalah menambahkan variable baru dari variable yang tersedia.
#
# 4. Oversampling
# 5. Train-Test Splitting
# 6. Modeling: Yaitu memilih teknik pemodelan, dll.
# Model Selection
# 7. Memilih model yang paling memiliki accuracy paling tinggi untuk dijadikan bahan prediksi
# 8. Cross-Validation
#
#
# ![Screenshot 2022-04-17 at 14.34.00.png](data:image/png;base64,...)
#
# Hal ini sesuai dengan metodologi dari CROSS INDUSTRY STANDARDS PROCESS FOR DATA MINING (CRISP-DM) yaitu:
# 1. Business Understanding
# 2.Data Understanding
# 3. Data Preparation:
# 4. Modeling
# 5. Evaluation
#
# ![Screenshot 2022-04-15 at 10.04.12.png](data:image/png;base64,...)
